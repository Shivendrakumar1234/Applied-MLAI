# %%
import pandas as pd 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\dell\Downloads\insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age,df.bought_insurance,marker='+',color='red')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['age']],df['bought_insurance'] ,test_size=0.2)

# %%
x_test
# Out:
#     age
# 8    62
# 16   25
# 17   58
# 23   45
# 11   28
# 18   19

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
x_test
# Out:
#     age
# 8    62
# 16   25
# 17   58
# 23   45
# 11   28
# 18   19

# %%
y_predicted = model.predict(x_test)

# %%
model.predict_proba(x_test)
# Out:
# array([[0.04110883, 0.95889117],
#        [0.9393722 , 0.0606278 ],
#        [0.07496595, 0.92503405],
#        [0.39094719, 0.60905281],
#        [0.90575658, 0.09424342],
#        [0.97576906, 0.02423094]])

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
y_predicted
# Out:
# array([1, 0, 1, 1, 0, 0])

# %%
x_test
# Out:
#     age
# 8    62
# 16   25
# 17   58
# 23   45
# 11   28
# 18   19

# %%
model.coef_
# Out:
# array([[0.15918954]])

# %%
model.intercept_
# Out:
# array([-6.72019671])

# %%
import math
def sigmoid(x):
    return 1/(1+math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042*age-1.53# 0.15918954~0.16 and -6.72019671~ -6.73
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705
